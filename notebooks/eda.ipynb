# %%
import pandas as pd

# %%
df=pd.read_csv('gpareport23.csv')
df
# Out:
#     AVERAGE Semester UNDERGRADUATE GRADE POINT AVERAGES\nUNIVERSITY OF WISCONSIN-MADISON\nFIRST SEMESTER 2023-2024\nJun 18, 2024  \
# 0    Grade point average is calculated by dividing ...
# 1                                                  NaN
# 2    Only the letter grades A, AB, B, BC, C, D, and...
# 3    This report prepared by the Office of the Regi...
# 4                                             FRESHMEN
# ..                                                 ...
# 261                              Nursing Undergraduate
# 262                                        Pre-Nursing
# 263                                           Pharmacy
# 264                          Pharmacology & Toxicology
# 265                                              Total
#
#                                             Unnamed: 1  Unnamed: 2  \
# 0                                                  NaN         NaN
# 1    Letter Grades A = Excellent\nAB = Intermediate...         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 261                                                NaN         NaN
# 262                                                NaN       157.0
# 263                                                NaN         NaN
# 264                                                NaN         NaN
# 265                                                NaN      3043.0
#
#                                             Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0                                                  NaN        NaN         NaN
# 1    Grade Points Per Credit\n4.0\n3.5\n3.0\n2.5\n2...        NaN         NaN
# 2                                                  NaN        NaN         NaN
# 3                                                  NaN        NaN         NaN
# 4                                                  NaN        NaN  SOPHOMORES
# ..                                                 ...        ...         ...
# 261                                                NaN        NaN         NaN
# 262                                                NaN      3.266         NaN
# 263                                                NaN        NaN         NaN
# 264                                                NaN        NaN         NaN
# 265                                                NaN      3.391         NaN
#
#     Unnamed: 6 Unnamed: 7                                         Unnamed: 8  \
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN  JUNIORS              SENIORS                  ...
# ..         ...        ...                                                ...
# 261        NaN        NaN                                                NaN
# 262        165      3.378                                                NaN
# 263        NaN        NaN                                                NaN
# 264        NaN        NaN                                                NaN
# 265       4517      3.428                                                NaN
#
#     Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 261         80       3.612         192       3.719         272       3.685
# 262         85       3.490           7       3.282         414       3.356
# 263         12       3.668          16       3.547          28       3.598
# 264         12       3.668          16       3.547          28       3.598
# 265       5181       3.496        6006       3.603       18747       3.496
#
# [266 rows x 15 columns]

# %%
with open('gpareport23.csv', 'r', encoding='utf-8', errors='ignore') as file:
    content = file.read()  # Read the entire content of the file

# Split content by newline character
data= content.split('\n')
raw_data=data[31:]
# Print the first few lines
for i, line in enumerate(raw_data[:266]):  # Show the first 10 lines
    print(f"Line {i+1}: {line}")
# Out:
# Line 1: Business,,427,,3.352,,826,3.408,,1083,3.428,1323,3.533,3659,3.452
# Line 2: Education,,372,,3.452,,454,3.505,,600,3.673,654,3.711,2080,3.609
# Line 3: Engineering,,617,,3.228,,1173,3.303,,1074,3.322,1796,3.516,4660,3.377
# Line 4: Human Ecology,,269,,3.423,,521,3.509,,753,3.567,747,3.607,2290,3.550
# Line 5: Letters and Science,,3151,,3.365,,4666,3.424,,5097,3.443,5783,3.534,18697,3.452
# Line 6: Nursing,,172,,3.276,,192,3.350,,203,3.537,323,3.645,890,3.469
# Line 7: Pharmacy,,,,,,,,,17,3.637,29,3.584,46,3.604
# Line 8: Undergraduate Men by School/College,,,,,,,,,,,,,,
# Line 9: Total,,2368,,3.298,,3947,3.373,,4528,3.384,5749,3.475,16592,3.400
# Line 244: Music Cert Prog,,2,,,,7,3.857,,7,3.861,3,,19,3.861
# Line 245: Social Work,,,,,,,,,3,,39,3.830,42,3.798
# Line 246: Nursing,,157,,3.266,,165,3.378,,172,3.547,267,3.660,761,3.475
# Line 247: Nursing Accelerated,,,,,,,,,,,34,3.545,34,3.545
# Line 248: Nursing Collaborative Program,,,,,,,,,7,3.667,34,3.488,41,3.525
# Line 249: Nursing Undergraduate,,,,,,,,,80,3.612,192,3.719,272,3.685
# Line 250: Pre-Nursing,,157,,3.266,,165,3.378,,85,3.490,7,3.282,414,3.356
# Line 251: Pharmacy,,,,,,,,,12,3.668,16,3.547,28,3.598
# Line 252: Pharmacology & Toxicology,,,,,,,,,12,3.668,16,3.547,28,3.598
# Line 253: Total,,3043,,3.391,,4517,3.428,,5181,3.496,6006,3.603,18747,3.496

# %% [markdown]
# I convereted the excel file into csv for easier manipulation of data.. it was very hard to understand anything from the excel.
# I made it into a data frame but there is one significant problem right now:
#     - there is no clear split between teh data if u can see in the dataframe, it just random data, so we have to figure out a way to split the data atleaset by grade level. I tried the /n method, we now have to extract the lines we want from there.

# %%
df.shape
# Out:
# (266, 15)

# %%
df.columns
# Out:
# Index(['AVERAGE Semester UNDERGRADUATE GRADE POINT AVERAGES\nUNIVERSITY OF WISCONSIN-MADISON\nFIRST SEMESTER 2023-2024\nJun 18, 2024',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     AVERAGE Semester UNDERGRADUATE GRADE POINT AVERAGES\nUNIVERSITY OF WISCONSIN-MADISON\nFIRST SEMESTER 2023-2024\nJun 18, 2024  \
# 0    Grade point average is calculated by dividing ...
# 1                                                  NaN
# 2    Only the letter grades A, AB, B, BC, C, D, and...
# 3    This report prepared by the Office of the Regi...
# 4                                             FRESHMEN
# ..                                                 ...
# 261                              Nursing Undergraduate
# 262                                        Pre-Nursing
# 263                                           Pharmacy
# 264                          Pharmacology & Toxicology
# 265                                              Total
#
#                                             Unnamed: 1  Unnamed: 2  \
# 0                                                  NaN         NaN
# 1    Letter Grades A = Excellent\nAB = Intermediate...         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 261                                                NaN         NaN
# 262                                                NaN       157.0
# 263                                                NaN         NaN
# 264                                                NaN         NaN
# 265                                                NaN      3043.0
#
#                                             Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0                                                  NaN        NaN         NaN
# 1    Grade Points Per Credit\n4.0\n3.5\n3.0\n2.5\n2...        NaN         NaN
# 2                                                  NaN        NaN         NaN
# 3                                                  NaN        NaN         NaN
# 4                                                  NaN        NaN  SOPHOMORES
# ..                                                 ...        ...         ...
# 261                                                NaN        NaN         NaN
# 262                                                NaN      3.266         NaN
# 263                                                NaN        NaN         NaN
# 264                                                NaN        NaN         NaN
# 265                                                NaN      3.391         NaN
#
#     Unnamed: 6 Unnamed: 7                                         Unnamed: 8  \
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN  JUNIORS              SENIORS                  ...
# ..         ...        ...                                                ...
# 261        NaN        NaN                                                NaN
# 262        165      3.378                                                NaN
# 263        NaN        NaN                                                NaN
# 264        NaN        NaN                                                NaN
# 265       4517      3.428                                                NaN
#
#     Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 261         80       3.612         192       3.719         272       3.685
# 262         85       3.490           7       3.282         414       3.356
# 263         12       3.668          16       3.547          28       3.598
# 264         12       3.668          16       3.547          28       3.598
# 265       5181       3.496        6006       3.603       18747       3.496
#
# [266 rows x 15 columns]>

# %%
df.info
# Out:
# <bound method DataFrame.info of     AVERAGE Semester UNDERGRADUATE GRADE POINT AVERAGES\nUNIVERSITY OF WISCONSIN-MADISON\nFIRST SEMESTER 2023-2024\nJun 18, 2024  \
# 0    Grade point average is calculated by dividing ...
# 1                                                  NaN
# 2    Only the letter grades A, AB, B, BC, C, D, and...
# 3    This report prepared by the Office of the Regi...
# 4                                             FRESHMEN
# ..                                                 ...
# 261                              Nursing Undergraduate
# 262                                        Pre-Nursing
# 263                                           Pharmacy
# 264                          Pharmacology & Toxicology
# 265                                              Total
#
#                                             Unnamed: 1  Unnamed: 2  \
# 0                                                  NaN         NaN
# 1    Letter Grades A = Excellent\nAB = Intermediate...         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 261                                                NaN         NaN
# 262                                                NaN       157.0
# 263                                                NaN         NaN
# 264                                                NaN         NaN
# 265                                                NaN      3043.0
#
#                                             Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0                                                  NaN        NaN         NaN
# 1    Grade Points Per Credit\n4.0\n3.5\n3.0\n2.5\n2...        NaN         NaN
# 2                                                  NaN        NaN         NaN
# 3                                                  NaN        NaN         NaN
# 4                                                  NaN        NaN  SOPHOMORES
# ..                                                 ...        ...         ...
# 261                                                NaN        NaN         NaN
# 262                                                NaN      3.266         NaN
# 263                                                NaN        NaN         NaN
# 264                                                NaN        NaN         NaN
# 265                                                NaN      3.391         NaN
#
#     Unnamed: 6 Unnamed: 7                                         Unnamed: 8  \
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN  JUNIORS              SENIORS                  ...
# ..         ...        ...                                                ...
# 261        NaN        NaN                                                NaN
# 262        165      3.378                                                NaN
# 263        NaN        NaN                                                NaN
# 264        NaN        NaN                                                NaN
# 265       4517      3.428                                                NaN
#
#     Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 261         80       3.612         192       3.719         272       3.685
# 262         85       3.490           7       3.282         414       3.356
# 263         12       3.668          16       3.547          28       3.598
# 264         12       3.668          16       3.547          28       3.598
# 265       5181       3.496        6006       3.603       18747       3.496
#
# [266 rows x 15 columns]>

# %%
df.isnull().sum()
# Out:
# AVERAGE Semester UNDERGRADUATE GRADE POINT AVERAGES\nUNIVERSITY OF WISCONSIN-MADISON\nFIRST SEMESTER 2023-2024\nJun 18, 2024      1
# Unnamed: 1                                                                                                                      265
# Unnamed: 2                                                                                                                       89
# Unnamed: 3                                                                                                                      265
# Unnamed: 4                                                                                                                      124
# Unnamed: 5                                                                                                                      262
# Unnamed: 6                                                                                                                       61
# Unnamed: 7                                                                                                                      108
# Unnamed: 8                                                                                                                      262
# Unnamed: 9                                                                                                                       44
# Unnamed: 10                                                                                                                      82
# Unnamed: 11                                                                                                                      35
# Unnamed: 12                                                                                                                      64
# Unnamed: 13                                                                                                                      21
# Unnamed: 14                                                                                                                      41
# dtype: int64

# %%
df['Unnamed: 1']
# Out:
# 0                                                    NaN
# 1      Letter Grades A = Excellent\nAB = Intermediate...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#                              ...
# 261                                                  NaN
# 262                                                  NaN
# 263                                                  NaN
# 264                                                  NaN
# 265                                                  NaN
# Name: Unnamed: 1, Length: 266, dtype: object

# %%
numeric_data = df.select_dtypes(include=['number'])
numeric_data.columns.tolist()
numeric_data
# Out:
#      Unnamed: 2
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 261         NaN
# 262       157.0
# 263         NaN
# 264         NaN
# 265      3043.0
#
# [266 rows x 1 columns]

# %%
df['Unnamed: 1'].fillna(df['Unnamed: 1'].mean(),inplace=False)
# # df['U'].fillna(df['column_name'].mean(), inplace=True)
# df['Unnamed: 2'].fillna(df['Unnamed: 2'].mean(),inplace=False)
# df['Unnamed: 3'].fillna(df['Unnamed: 3'].mean(),inplace=False)
# df['Unnamed: 4'].fillna(df['Unnamed: 4'].mean(),inplace=False)
# df['Unnamed: 5'].fillna(df['Unnamed: 5'].mean(),inplace=False)
# df['Unnamed: 6'].fillna(df['Unnamed: 6'].mean(),inplace=False)
# df['Unnamed: 7'].fillna(df['Unnamed: 7'].mean(),inplace=False)
# df['Unnamed: 8'].fillna(df['Unnamed: 8'].mean(),inplace=False)
# df['Unnamed: 9'].fillna(df['Unnamed: 9'].mean(),inplace=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df[Unnamed: 1].fillna(df[Unnamed: 1].mean(),inplace=False)
#       2 # # df['U'].fillna(df['column_name'].mean(), inplace=True)
#       3 # df['Unnamed: 2'].fillna(df['Unnamed: 2'].mean(),inplace=False)
#       4 # df['Unnamed: 3'].fillna(df['Unnamed: 3'].mean(),inplace=False)
#    (...)
#       9 # df['Unnamed: 8'].fillna(df['Unnamed: 8'].mean(),inplace=False)
#      10 # df['Unnamed: 9'].fillna(df['Unnamed: 9'].mean(),inplace=False)
#
# NameError: name 'Unnamed' is not defined

# %%
parsed_data = []

# Loop through each line and extract relevant information
for line in raw_data:
    # Split the line by commas
    parts = line.split(",,")
    print(pat)
    # Extract the college name from the first part
    college = parts[0].split(": ")[0].strip()
    
    # Extract GPA values for Freshmen, Sophomores, Juniors, Seniors
    # GPA values are at fixed positions in the split parts
    gpa_values = []
    for i in range(1, len(parts), 2):
        try:
        # Split and strip the parts, then access the second element
            gpa_str = parts[i].split(",")[1].strip()  # Strip any trailing spaces
            gpa = float(gpa_str)  # Convert to float
        except (IndexError, ValueError):
            gpa = None  # Handle missing or invalid values
    gpa_values.append(gpa)

    # Append the college name and GPA values to parsed_data
    parsed_data.append([college] + gpa_values)
print(parsed_data)
# # Create a DataFrame with grade levels as columns
# columns = [ "Freshmen", "Sophomores", "Juniors", "Seniors"]
# df = pd.DataFrame(parsed_data, columns=columns)

# # Display the DataFrame
# df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/internals/construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/internals/construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
#     991     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 4 columns passed, passed data had 2 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 35
#      32     # print(parsed_data)
#      33 # Create a DataFrame with grade levels as columns
#      34 columns = [ "Freshmen", "Sophomores", "Juniors", "Seniors"]
# ---> 35 df = pd.DataFrame(parsed_data, columns=columns)
#      37 # Display the DataFrame
#      38 df
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:851, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     849     if columns is not None:
#     850         columns = ensure_index(columns)
# --> 851     arrays, columns, index = nested_data_to_arrays(
#     852         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     853         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     854         data,
#     855         columns,
#     856         index,  # type: ignore[arg-type]
#     857         dtype,
#     858     )
#     859     mgr = arrays_to_mgr(
#     860         arrays,
#     861         columns,
#    (...)
#     864         typ=manager,
#     865     )
#     866 else:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/internals/construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/internals/construction.py:845, in to_arrays(data, columns, dtype)
#     842     data = [tuple(x) for x in data]
#     843     arr = _list_to_arrays(data)
# --> 845 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     846 return content, columns
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/internals/construction.py:942, in _finalize_columns_and_data(content, columns, dtype)
#     939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
# --> 942     raise ValueError(err) from err
#     944 if len(contents) and contents[0].dtype == np.object_:
#     945     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 4 columns passed, passed data had 2 columns

# %%
import re
# for line in raw_data:
#     # Split the line by commas
#     parts = line.split(",,")
#     # print(parts)
#     # Extract the college name from the first part
#     college = parts[0].split(": ")[0].strip()
# # Step 1: Prepare a list of unique grade levels
#     grade_levels = ['Freshman', 'Sophomore', 'Junior', 'Senior']
#     college = parts[0].split(": ")[0]
#     # print(college)
# Step 2: Prepare a dictionary to hold GPA values by grade level and college
gpa_data = {}
for line in data:
    parts = line.split(', ')  # Split by comma and space
    
    # First item is the college name
    college = parts[0]
    
    # Initialize the GPA data for this college
    gpa_data[college] = {}
# Step 3: Fill the dictionary with data
    for i in range(1, len(parts), 2):
        try:
        # Split and strip the parts, then access the second element
            gpa_str = parts[i].split(",")[1].strip()  # Strip any trailing spaces
            # gpa = float(gpa_str)  # Convert to float
        except (IndexError, ValueError):
            gpa = None  # Handle missing or invalid values
            gpa_values.append(gpa)
            # gpa_data[college][grade_level] = float(gpa)

# Step 4: Convert the dictionary to a DataFrame
df = pd.DataFrame(gpa_data)

# Step 5: Reorder the rows by grade level
df = df.reindex(grade_levels)

# Print the DataFrame
df
# Out:
#            "AVERAGE Semester UNDERGRADUATE GRADE POINT AVERAGES  \
# Freshman                                                 NaN
# Sophomore                                                NaN
# Junior                                                   NaN
# Senior                                                   NaN
#
#            UNIVERSITY OF WISCONSIN-MADISON  FIRST SEMESTER 2023-2024  Jun 18  \
# Freshman                               NaN                       NaN     NaN
# Sophomore                              NaN                       NaN     NaN
# Junior                                 NaN                       NaN     NaN
# Senior                                 NaN                       NaN     NaN
#
#            "Grade point average is calculated by dividing the number of grade points earned by the number of credits carried  \
# Freshman                                                 NaN
# Sophomore                                                NaN
# Junior                                                   NaN
# Senior                                                   NaN
#
#            ,"Letter Grades A = Excellent  AB = Intermediate B = Good  \
# Freshman                             NaN                         NaN
# Sophomore                            NaN                         NaN
# Junior                               NaN                         NaN
# Senior                               NaN                         NaN
#
#            BC = Intermediate  C = Fair  D = Poor  ...  \
# Freshman                 NaN       NaN       NaN  ...
# Sophomore                NaN       NaN       NaN  ...
# Junior                   NaN       NaN       NaN  ...
# Senior                   NaN       NaN       NaN  ...
#
#            Landscape Architecture,,3,,,,8,3.686,,11,3.909,14,3.465,36,3.671  \
# Freshman                                                 NaN
# Sophomore                                                NaN
# Junior                                                   NaN
# Senior                                                   NaN
#
#            Letters & Science Online,,,,,,1,,,2,,1,,4,  \
# Freshman                                          NaN
# Sophomore                                         NaN
# Junior                                            NaN
# Senior                                            NaN
#
#            Music,,2,,,,3,,,5,,5,,15,3.861  \
# Freshman                              NaN
# Sophomore                             NaN
# Junior                                NaN
# Senior                                NaN
#
#            Music Cert Prog,,2,,,,7,3.857,,7,3.861,3,,19,3.861  \
# Freshman                                                 NaN
# Sophomore                                                NaN
# Junior                                                   NaN
# Senior                                                   NaN
#
#            Social Work,,,,,,,,,3,,39,3.830,42,3.798  \
# Freshman                                        NaN
# Sophomore                                       NaN
# Junior                                          NaN
# Senior                                          NaN
#
#            Nursing Accelerated,,,,,,,,,,,34,3.545,34,3.545  \
# Freshman                                               NaN
# Sophomore                                              NaN
# Junior                                                 NaN
# Senior                                                 NaN
#
#            Nursing Collaborative Program,,,,,,,,,7,3.667,34,3.488,41,3.525  \
# Freshman                                                 NaN
# Sophomore                                                NaN
# Junior                                                   NaN
# Senior                                                   NaN
#
#            Nursing Undergraduate,,,,,,,,,80,3.612,192,3.719,272,3.685  \
# Freshman                                                 NaN
# Sophomore                                                NaN
# Junior                                                   NaN
# Senior                                                   NaN
#
#            Pre-Nursing,,157,,3.266,,165,3.378,,85,3.490,7,3.282,414,3.356  \
# Freshman                                                 NaN
# Sophomore                                                NaN
# Junior                                                   NaN
# Senior                                                   NaN
#
#            Pharmacology & Toxicology,,,,,,,,,12,3.668,16,3.547,28,3.598
# Freshman                                                 NaN
# Sophomore                                                NaN
# Junior                                                   NaN
# Senior                                                   NaN
#
# [4 rows x 240 columns]
